# %%
import pandas as pd

# %%
path = "Resources/data.csv"

data = pd.read_csv(path)

# %%
data.head()
# Out:
#      County 2020 Total Crash Fatalities 2020 Total Index Crimes Reported  \
# 0   APPLING                           6                              179
# 1  ATKINSON                           1                               91
# 2     BACON                           4                              186
# 3     BAKER                           3                                0
# 4   BALDWIN                          11                            1,376
#
#   2020 Model-Based Estimate of Median Household Income, Dollars  \
# 0                                           $44,871
# 1                                           $39,633
# 2                                           $41,756
# 3                                           $43,696
# 4                                           $49,350
#
#   2020 Average Weekly Wages, All Industries, Dollars 2020-21 Public Schools  \
# 0                                            $1,061                       6
# ...

# %%
df = data.query("County == 'CHEROKEE' | County == 'CLAYTON' | County == 'COBB' | County == 'DEKALB' | County == 'DOUGLAS' | County == 'FAYETTE' | County == 'FORSYTH' | County == 'FULTON' |County == 'GWINNETT' | County == 'HENRY' | County == 'ROCKDALE'")

atl_data = df.set_index(['County'])

atl_data
# Out:
#          2020 Total Crash Fatalities 2020 Total Index Crimes Reported  \
# County
# CHEROKEE                          21                            1,275
# CLAYTON                           49                            9,361
# COBB                              85                           13,515
# DEKALB                            92                           23,451
# DOUGLAS                           13                            3,464
# FAYETTE                            6                            1,359
# FORSYTH                           12                            1,231
# FULTON                           145                           13,581
# GWINNETT                          57                              285
# HENRY                             28                            2,169
# ROCKDALE                          17                               18
#
#          2020 Model-Based Estimate of Median Household Income, Dollars  \
# County
# ...

# %%
weather_data = atl[['Avg_Temp', 'Max_Temp', 'Min_Temp', 'Percipitation']]

weather_data
# Out:
#          Avg_Temp Max_Temp Min_Temp Percipitation
# County
# CHEROKEE   60.5°F   71.3°F   49.6°F        58.11"
# CLAYTON    63.3°F   73.9°F   52.6°F        51.23"
# COBB       61.9°F   72.7°F   51.2°F        54.20"
# DEKALB     62.6°F   73.4°F   51.9°F        52.41"
# DOUGLAS    62.2°F   73.1°F   51.2°F        57.63"
# FAYETTE    63.3°F   74.1°F   52.5°F        49.96"
# FORSYTH    60.4°F   71.3°F   49.5°F        55.72"
# FULTON     62.3°F   73.1°F   51.6°F        53.24"
# GWINNETT   59.6°F   70.1°F   49.1°F        67.84"
# HENRY      65.4°F   77.4°F   53.4°F        52.48"
# ROCKDALE   64.9°F   76.0°F   53.7°F        54.69"

# %%
# export
atl_data.to_csv('Resources/atl_data.csv', index=True)
weather_data.to_csv('Resources/weather_data.csv', index=True)
